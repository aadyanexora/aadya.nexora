# %% [markdown]
# # Endpoint Smoke Tests
#
# This notebook performs HTTP requests against the running backend to verify functionality (register, login, protected routes, admin ingest, chat).

# %%
import requests
BASE = "http://localhost:8000"
print("Begin API tests")
